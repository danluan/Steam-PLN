# %%
import pandas as pd
import glob, os, json

# https://softhints.com/merge-multiple-json-files-pandas-dataframe/
json_dir = './jsonsteam'

json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []   
for file in file_list:
    with open(file) as f:
        # Caminho do arquivo
        nome_arquivo = file

        # Lendo o arquivo e convertendo
        df_json = pd.read_json(nome_arquivo)

        # Nome do arquivo
        nome_arquivo = nome_arquivo[12:] 

        # Convertendo json 
        df_json = pd.json_normalize(df_json.reviews)

        # Criando a coluna com o nome do arquivo json (tratando posteriormente daria para separar a categoria e o nome do jogo)
        df_json['nome'] = nome_arquivo
    
    # Concatenando arq
    dfs.append(df_json)

dfs
df = pd.concat(dfs)
# Out:
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)
# C:\Users\GBFFO\AppData\Local\Temp\ipykernel_19796\2908929947.py:17: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_json = pd.read_json(nome_arquivo)

# %%
# Exibindo dados no pandas que foram convertidos e concatenados dos diversos jsons que estavam na pasta ./jsonsteam
df
# Out:
#    recommendationid   language  \
# 0         111776175  brazilian
# 1         108834430  brazilian
# 2         107570918  brazilian
# 3         105091278  brazilian
# 4         100653298  brazilian
# ..              ...        ...
# 11              NaN        NaN
# 12              NaN        NaN
# 13              NaN        NaN
# 14              NaN        NaN
# 15              NaN        NaN
#
#                                                review  timestamp_created  \
# 0   Que jogo irritante! Em uma hora eu morri 126 f...       1.646701e+09
# 1   jogo escondido que é muito foda, difícil e div...       1.643225e+09
# 2          Mesmo sofrimento de jogar The Invasion One       1.641620e+09
# 3                                              god :)       1.638473e+09
# 4   Dublagem bem ruim, mas é divertido e barato.\n...       1.633576e+09
# ..                                                ...                ...
# 11                                                NaN                NaN
# 12                                                NaN                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
#
#     timestamp_updated voted_up  votes_up  votes_funny   weighted_vote_score  \
# 0        1.646701e+09     True       0.0          0.0                     0
# 1        1.643225e+09     True       1.0          0.0  0.523809552192687988
# 2        1.641620e+09     True       0.0          0.0                     0
# 3        1.638473e+09     True       0.0          0.0                     0
# 4        1.633576e+09     True       0.0          0.0                     0
# ..                ...      ...       ...          ...                   ...
# 11                NaN      NaN       NaN          NaN                   NaN
# 12                NaN      NaN       NaN          NaN                   NaN
# 13                NaN      NaN       NaN          NaN                   NaN
# 14                NaN      NaN       NaN          NaN                   NaN
# 15                NaN      NaN       NaN          NaN                   NaN
#
#     comment_count  ...     author.steamid author.num_games_owned  \
# 0             0.0  ...  76561198274286779                   19.0
# 1             0.0  ...  76561198965988838                   30.0
# 2             0.0  ...  76561198872422320                   67.0
# 3             0.0  ...  76561199224325815                  904.0
# 4             0.0  ...  76561198843966069                  125.0
# ..            ...  ...                ...                    ...
# 11            NaN  ...                NaN                    NaN
# 12            NaN  ...                NaN                    NaN
# 13            NaN  ...                NaN                    NaN
# 14            NaN  ...                NaN                    NaN
# 15            NaN  ...                NaN                    NaN
#
#    author.num_reviews author.playtime_forever  author.playtime_last_two_weeks  \
# 0                 3.0                   128.0                            65.0
# 1                 7.0                   136.0                             0.0
# 2                36.0                   124.0                             0.0
# 3                 1.0                   331.0                             0.0
# 4                 4.0                    42.0                             0.0
# ..                ...                     ...                             ...
# 11                NaN                     NaN                             NaN
# 12                NaN                     NaN                             NaN
# 13                NaN                     NaN                             NaN
# 14                NaN                     NaN                             NaN
# 15                NaN                     NaN                             NaN
#
#     author.playtime_at_review  author.last_played  \
# 0                        78.0        1.647391e+09
# 1                        38.0        1.643997e+09
# 2                       124.0        1.633654e+09
# 3                       331.0        1.638430e+09
# 4                        12.0        1.633627e+09
# ..                        ...                 ...
# 11                        NaN                 NaN
# 12                        NaN                 NaN
# 13                        NaN                 NaN
# 14                        NaN                 NaN
# 15                        NaN                 NaN
#
#                                 nome  timestamp_dev_responded  \
# 0            Action_2Ninjas1Cup.json                      NaN
# 1            Action_2Ninjas1Cup.json                      NaN
# 2            Action_2Ninjas1Cup.json                      NaN
# 3            Action_2Ninjas1Cup.json                      NaN
# 4            Action_2Ninjas1Cup.json                      NaN
# ..                               ...                      ...
# 11  Strategy_ZomboBusterAdvance.json                      NaN
# 12  Strategy_ZomboBusterAdvance.json                      NaN
# 13  Strategy_ZomboBusterAdvance.json                      NaN
# 14  Strategy_ZomboBusterAdvance.json                      NaN
# 15  Strategy_ZomboBusterAdvance.json                      NaN
#
#     developer_response
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
#
# [2516 rows x 23 columns]

# %%
df.describe()
# Out:
#        timestamp_created  timestamp_updated     votes_up  votes_funny  \
# count       2.205000e+03       2.205000e+03  2205.000000  2205.000000
# mean        1.602384e+09       1.603278e+09     1.092517     0.301587
# std         5.799023e+07       5.722874e+07     5.139397     2.564631
# min         1.323705e+09       1.323705e+09     0.000000     0.000000
# 25%         1.604067e+09       1.604797e+09     0.000000     0.000000
# 50%         1.625165e+09       1.625420e+09     0.000000     0.000000
# 75%         1.638989e+09       1.639148e+09     0.000000     0.000000
# max         1.648263e+09       1.648263e+09   146.000000    96.000000
#
#        comment_count  author.num_games_owned  author.num_reviews  \
# count    2205.000000             2205.000000         2205.000000
# mean        0.052154              230.628118           40.351020
# std         0.537607              607.453309          143.179701
# min         0.000000                1.000000            1.000000
# 25%         0.000000               24.000000            2.000000
# 50%         0.000000               61.000000            6.000000
# 75%         0.000000              169.000000           19.000000
# max        20.000000            10222.000000         1491.000000
#
#        author.playtime_forever  author.playtime_last_two_weeks  \
# count              2205.000000                     2205.000000
# mean               8370.259864                      133.845351
# std               21455.569971                      570.625302
# min                   5.000000                        0.000000
# 25%                 389.000000                        0.000000
# 50%                2057.000000                        0.000000
# 75%                7460.000000                        0.000000
# max              327915.000000                     8152.000000
#
#        author.playtime_at_review  author.last_played  timestamp_dev_responded
# count                2201.000000        2.205000e+03             1.400000e+01
# mean                 5644.266243        1.611477e+09             1.605514e+09
# std                 15793.232079        5.630132e+07             1.316073e+07
# min                     4.000000        1.328688e+09             1.594830e+09
# 25%                   253.000000        1.610205e+09             1.595034e+09
# 50%                   841.000000        1.639283e+09             1.597926e+09
# 75%                  4104.000000        1.644887e+09             1.612862e+09
# max                204985.000000        1.648400e+09             1.628271e+09
